# %% [markdown]
# # Hyperelastic Model Fitting

# %%
# %load_ext autoreload
# %autoreload 2
# %matmodlab bokeh
from pandas import read_excel
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
# Populating the interactive namespace from matmodlab and bokeh

# %% [markdown]
# ## Experimental Data

# %%
# uniaxial data
udf = read_excel('Treloar_hyperelastic_data.xlsx', sheetname='Uniaxial')
ud = udf.as_matrix(columns=('Engineering Strain', 'Engineering Stress (MPa)'))

# Biaxial data
bdf = read_excel('Treloar_hyperelastic_data.xlsx', sheetname='Biaxial')
bd = bdf.as_matrix(columns=('Engineering Strain', 'Engineering Stress (MPa)'))

# Pure shear data
sdf = read_excel('Treloar_hyperelastic_data.xlsx', sheetname='Pure Shear')
sd = sdf.as_matrix(columns=('Engineering Strain', 'Engineering Stress (MPa)'))

# %% [markdown]
# ## Uniaxial Data
#
# Find the optimal fit to the uniaxial stress data with a hyperelastic polynomial model.  The symbolic constant `UNIAXIAL_DATA` instructs `hyperopt` to interpret the input data as coming from a uniaxial stress experiment.

# %%
uf = hyperopt(UNIAXIAL_DATA, ud[:,0], ud[:,1])
print uf.summary()
# Out:
#             Data type: Uniaxial
# Number of data points: 23
#      Polynomial order: 5
#         I2 dependence: True
#            Parameters: C10=-395859933.045, C01=132250968.904, C20=-134170727.507, C11=104493666.738, C02=-33928679.075, C30=11734697.899, C21=-11610156.849, C12=-24806492.415, C03=17653757.438, C40=-4337674.748, C31=-4054457.364, C22=-1034831.948, C13=3875358.131, C04=9768482.730, C50=-270732.550, C41=901202.455, C32=-1893102.941, C23=989459.036, C14=4834111.469, C05=-3146197.619
#                 Error: 0.0198322188292

# %% [markdown]
# At this point, the optimal parameters have been determined and are accessible with the `popt` attribute:

# %%
uf.popt
# Out:
# array([ -3.95859933e+08,   1.32250969e+08,  -1.34170728e+08,
#          1.04493667e+08,  -3.39286791e+07,   1.17346979e+07,
#         -1.16101568e+07,  -2.48064924e+07,   1.76537574e+07,
#         -4.33767475e+06,  -4.05445736e+06,  -1.03483195e+06,
#          3.87535813e+06,   9.76848273e+06,  -2.70732550e+05,
#          9.01202455e+05,  -1.89310294e+06,   9.89459036e+05,
#          4.83411147e+06,  -3.14619762e+06])

# %% [markdown]
# The optimal parameters are also available as a dictionary via the `todict` method:

# %%
uf.todict()
# Out:
# {'C01': 132250968.90355907,
#  'C02': -33928679.074741118,
#  'C03': 17653757.438015793,
#  'C04': 9768482.730201792,
#  'C05': -3146197.6186751584,
#  'C10': -395859933.04529548,
#  'C11': 104493666.73756613,
#  'C12': -24806492.414594918,
#  'C13': 3875358.1313264915,
#  'C14': 4834111.4689746331,
#  'C20': -134170727.5069174,
#  'C21': -11610156.84929673,
#  'C22': -1034831.9476936288,
#  'C23': 989459.03600392921,
#  'C30': 11734697.899416655,
#  'C31': -4054457.3641825169,
#  'C32': -1893102.9406949782,
#  'C40': -4337674.7481137849,
#  'C41': 901202.45488339872,
#  'C50': -270732.54991535202}

# %% [markdown]
# The error in the fit:

# %%
uf.error
# Out:
# 0.0198322188292

# %% [markdown]
# Plots are generated with the `bp_plot` method

# %%
show(uf.bp_plot())
# Out:
#     <div class="plotdiv" id="466cca28-0d37-4db1-83c8-442728318246"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("466cca28-0d37-4db1-83c8-442728318246");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '466cca28-0d37-4db1-83c8-442728318246' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3ba19907-2983-440b-95d0-b819d65222bb": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}, "legends": [["Uniaxial Data, data", [{"type": "GlyphRenderer", "id": "cea5ef6a-32b6-4368-8e0a-7d34a5426b78"}]], ["Uniaxial Data, fit", [{"type": "GlyphRenderer", "id": "ba492051-b885-4ae7-9e04-5d26e0258873"}]]]}, "type": "Legend", "id": "72ec9728-d7e0-48ed-9c88-1c99a9d9d641"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [152113.86, 239040.27, 304237.53, 412893.09, 521548.65, 586736.1, 673662.51, 869244.48, 1043087.49, 1216940.31, 1586365.29, 1955790.27, 2303486.1, 2694650.04, 3042345.87, 3390041.7, 3759466.68, 4128891.66, 4476587.49, 4846012.47, 5215447.26, 5584872.24, 6301993.05], "x": [0.1338, 0.2675, 0.3567, 0.6242, 0.8917, 1.1592, 1.4268, 2.051, 2.586, 3.0318, 3.7898, 4.3694, 4.8153, 5.172, 5.4395, 5.707, 5.9299, 6.0637, 6.1975, 6.3312, 6.465, 6.5541, 6.6433]}}, "type": "ColumnDataSource", "id": "a8c98bd4-c1ba-4375-91b7-b539f67c092f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}}, "type": "ResetTool", "id": "90f7a668-849d-4e4d-9b26-a25197017dbb"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "4383a1bc-346d-40d4-86e3-b7f81bd3b654"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "ddc1f218-5d49-4623-9dbf-6506b9ffbfd0"}, "y_range": {"type": "DataRange1d", "id": "4383a1bc-346d-40d4-86e3-b7f81bd3b654"}, "renderers": [{"type": "LinearAxis", "id": "3ddbd2c6-5e77-4134-afec-4236776fae1d"}, {"type": "Grid", "id": "602e4e60-590e-4b5c-92e3-9151e264994c"}, {"type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}, {"type": "Grid", "id": "1c0be74c-0e18-471f-8984-99b4a710b07a"}, {"type": "BoxAnnotation", "id": "2dc9216c-89d1-4b02-a6cc-1f99fb35a1f3"}, {"type": "Legend", "id": "72ec9728-d7e0-48ed-9c88-1c99a9d9d641"}, {"type": "GlyphRenderer", "id": "cea5ef6a-32b6-4368-8e0a-7d34a5426b78"}, {"type": "GlyphRenderer", "id": "ba492051-b885-4ae7-9e04-5d26e0258873"}], "below": [{"type": "LinearAxis", "id": "3ddbd2c6-5e77-4134-afec-4236776fae1d"}], "tool_events": {"type": "ToolEvents", "id": "4faf175b-701e-4f85-80d5-9d343b3ce641"}, "tools": [{"type": "ResizeTool", "id": "3837860c-0c6c-48c7-a188-b5e717c582ab"}, {"type": "PanTool", "id": "23b7cc26-28ea-4e52-8d2a-a84efe41dc8b"}, {"type": "WheelZoomTool", "id": "88c5a117-ed5b-475a-a801-c0d89769d32d"}, {"type": "BoxZoomTool", "id": "37afa29d-1beb-4925-be2f-eba573a29741"}, {"type": "ResetTool", "id": "90f7a668-849d-4e4d-9b26-a25197017dbb"}, {"type": "PreviewSaveTool", "id": "602f7cfc-1984-45c7-89bd-cbdec5f17f5b"}], "left": [{"type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}]}, "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c", "subtype": "Figure"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "59d490ca-3778-4601-92e5-c942ca08961d"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}}, "type": "PreviewSaveTool", "id": "602f7cfc-1984-45c7-89bd-cbdec5f17f5b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}, "formatter": {"type": "BasicTickFormatter", "id": "1763db03-6e2f-4576-b1b8-8ccf3e704c10"}, "ticker": {"type": "BasicTicker", "id": "e2d82171-88f5-447d-b812-7bb77b5086b2"}}, "type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}}, "type": "WheelZoomTool", "id": "88c5a117-ed5b-475a-a801-c0d89769d32d"}, {"attributes": {}, "type": "BasicTicker", "id": "e2d82171-88f5-447d-b812-7bb77b5086b2"}, {"attributes": {"nonselection_glyph": ...

# %% [markdown]
# ## Biaxial Data
#
# Biaxial data is fit in a similar manner:

# %%
bf = hyperopt(BIAXIAL_DATA, bd[:,0], bd[:,1])
print bf.summary()
show(bf.bp_plot())
# Out:
#             Data type: Biaxial
# Number of data points: 16
#      Polynomial order: 4
#         I2 dependence: True
#            Parameters: C10=48126616.023, C01=-14323537.793, C20=597202131.473, C11=-420483882.811, C02=108970996.079, C30=416916020.562, C21=-85123697.713, C12=-35925284.204, C03=-3410748.604, C40=105722602.577, C31=9671542.604, C22=2942836.173, C13=-267685.707, C04=16785.785
#                 Error: 0.00990862004187
#     <div class="plotdiv" id="b803d8d5-9e92-4981-880c-1dc0bb607209"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b803d8d5-9e92-4981-880c-1dc0bb607209");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b803d8d5-9e92-4981-880c-1dc0bb607209' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"87b510c2-f537-46de-b4d7-0006eddac8ad": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c", "73dfb66b-d4dd-4646-921a-8fe53992f772"], "references": [{"attributes": {}, "type": "ToolEvents", "id": "5c1943a8-faa9-4516-89e6-3c552d324b20"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "c524c00c-e400-4de6-a006-12ec1823702c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}, "legends": [["Uniaxial Data, data", [{"type": "GlyphRenderer", "id": "cea5ef6a-32b6-4368-8e0a-7d34a5426b78"}]], ["Uniaxial Data, fit", [{"type": "GlyphRenderer", "id": "ba492051-b885-4ae7-9e04-5d26e0258873"}]]]}, "type": "Legend", "id": "72ec9728-d7e0-48ed-9c88-1c99a9d9d641"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "73dfb66b-d4dd-4646-921a-8fe53992f772"}, "formatter": {"type": "BasicTickFormatter", "id": "9048309c-52b1-42bd-933f-b231c8fffaf0"}, "ticker": {"type": "BasicTicker", "id": "3afca995-5fc1-428a-9f53-c28d48355f0c"}}, "type": "LinearAxis", "id": "8b5dd124-c7f6-4a6a-96bd-d62f40c353e9"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}}, "type": "ResetTool", "id": "90f7a668-849d-4e4d-9b26-a25197017dbb"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "e235baed-4c65-46bd-aac2-b86e616f20c9"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "4383a1bc-346d-40d4-86e3-b7f81bd3b654"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "ddc1f218-5d49-4623-9dbf-6506b9ffbfd0"}, "y_range": {"type": "DataRange1d", "id": "4383a1bc-346d-40d4-86e3-b7f81bd3b654"}, "renderers": [{"type": "LinearAxis", "id": "3ddbd2c6-5e77-4134-afec-4236776fae1d"}, {"type": "Grid", "id": "602e4e60-590e-4b5c-92e3-9151e264994c"}, {"type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}, {"type": "Grid", "id": "1c0be74c-0e18-471f-8984-99b4a710b07a"}, {"type": "BoxAnnotation", "id": "2dc9216c-89d1-4b02-a6cc-1f99fb35a1f3"}, {"type": "Legend", "id": "72ec9728-d7e0-48ed-9c88-1c99a9d9d641"}, {"type": "GlyphRenderer", "id": "cea5ef6a-32b6-4368-8e0a-7d34a5426b78"}, {"type": "GlyphRenderer", "id": "ba492051-b885-4ae7-9e04-5d26e0258873"}], "below": [{"type": "LinearAxis", "id": "3ddbd2c6-5e77-4134-afec-4236776fae1d"}], "tool_events": {"type": "ToolEvents", "id": "4faf175b-701e-4f85-80d5-9d343b3ce641"}, "tools": [{"type": "ResizeTool", "id": "3837860c-0c6c-48c7-a188-b5e717c582ab"}, {"type": "PanTool", "id": "23b7cc26-28ea-4e52-8d2a-a84efe41dc8b"}, {"type": "WheelZoomTool", "id": "88c5a117-ed5b-475a-a801-c0d89769d32d"}, {"type": "BoxZoomTool", "id": "37afa29d-1beb-4925-be2f-eba573a29741"}, {"type": "ResetTool", "id": "90f7a668-849d-4e4d-9b26-a25197017dbb"}, {"type": "PreviewSaveTool", "id": "602f7cfc-1984-45c7-89bd-cbdec5f17f5b"}], "left": [{"type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}]}, "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c", "subtype": "Figure"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "59d490ca-3778-4601-92e5-c942ca08961d"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [152113.86, 239040.27, 304237.53, 412893.09, 521548.65, 586736.1, 673662.51, 869244.48, 1043087.49, 1216940.31, 1586365.29, 1955790.27, 2303486.1, 2694650.04, 3042345.87, 3390041.7, 3759466.68, 4128891.66, 4476587.49, 4846012.47, 5215447.26, 5584872.24, 6301993.05], "x": [0.1338, 0.2675, 0.3567, 0.6242, 0.8917, 1.1592, 1.4268, 2.051, 2.586, 3.0318, 3.7898, 4.3694, 4.8153, 5.172, 5.4395, 5.707, 5.9299, 6.0637, 6.1975, 6.3312, 6.465, 6.5541, 6.6433]}}, "type": "ColumnDataSource", "id": "a8c98bd4-c1ba-4375-91b7-b539f67c092f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63 ...

# %% [markdown]
# ## Shear Data
#
# Lastly, the shear data is fit

# %%
sf = hyperopt(SHEAR_DATA, sd[:,0], sd[:,1])
print sf.summary()
show(sf.bp_plot())
# Out:
#             Data type: Shear
# Number of data points: 13
#      Polynomial order: 3
#         I2 dependence: True
#            Parameters: C10=-480403082.071, C01=161106124.736, C20=-278863992.929, C11=38177864.867, C02=56699970.680, C30=-29401178.157, C21=-4432.913, C12=2952118.412, C03=-752519.876
#                 Error: 0.0182429252418
#     <div class="plotdiv" id="faba37d5-b9fc-4f9d-9138-f7c2423bb5ed"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("faba37d5-b9fc-4f9d-9138-f7c2423bb5ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'faba37d5-b9fc-4f9d-9138-f7c2423bb5ed' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"49fc272f-13c4-436a-9761-d4ffdc15feed": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c", "73dfb66b-d4dd-4646-921a-8fe53992f772", "8117b6fe-12e9-45a2-b67f-bd02c7e13b5a"], "references": [{"attributes": {}, "type": "ToolEvents", "id": "5c1943a8-faa9-4516-89e6-3c552d324b20"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "c524c00c-e400-4de6-a006-12ec1823702c"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "24dd3ebc-27be-454d-a85b-c073fb238822"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "73dfb66b-d4dd-4646-921a-8fe53992f772"}, "formatter": {"type": "BasicTickFormatter", "id": "9048309c-52b1-42bd-933f-b231c8fffaf0"}, "ticker": {"type": "BasicTicker", "id": "3afca995-5fc1-428a-9f53-c28d48355f0c"}}, "type": "LinearAxis", "id": "8b5dd124-c7f6-4a6a-96bd-d62f40c353e9"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "1763db03-6e2f-4576-b1b8-8ccf3e704c10"}, {"attributes": {"nonselection_glyph": {"type": "Circle", "id": "0af01688-cdb4-4fa2-9c84-46771f7906c9"}, "data_source": {"type": "ColumnDataSource", "id": "aedaf246-1022-4c7f-87b0-a6ae7768d1a7"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "99dbbf79-874c-4070-a5e8-f97c71d4e221"}}, "type": "GlyphRenderer", "id": "842936b4-a6ff-4725-a815-0f6b547fd826"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "4383a1bc-346d-40d4-86e3-b7f81bd3b654"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "ddc1f218-5d49-4623-9dbf-6506b9ffbfd0"}, "y_range": {"type": "DataRange1d", "id": "4383a1bc-346d-40d4-86e3-b7f81bd3b654"}, "renderers": [{"type": "LinearAxis", "id": "3ddbd2c6-5e77-4134-afec-4236776fae1d"}, {"type": "Grid", "id": "602e4e60-590e-4b5c-92e3-9151e264994c"}, {"type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}, {"type": "Grid", "id": "1c0be74c-0e18-471f-8984-99b4a710b07a"}, {"type": "BoxAnnotation", "id": "2dc9216c-89d1-4b02-a6cc-1f99fb35a1f3"}, {"type": "Legend", "id": "72ec9728-d7e0-48ed-9c88-1c99a9d9d641"}, {"type": "GlyphRenderer", "id": "cea5ef6a-32b6-4368-8e0a-7d34a5426b78"}, {"type": "GlyphRenderer", "id": "ba492051-b885-4ae7-9e04-5d26e0258873"}], "below": [{"type": "LinearAxis", "id": "3ddbd2c6-5e77-4134-afec-4236776fae1d"}], "tool_events": {"type": "ToolEvents", "id": "4faf175b-701e-4f85-80d5-9d343b3ce641"}, "tools": [{"type": "ResizeTool", "id": "3837860c-0c6c-48c7-a188-b5e717c582ab"}, {"type": "PanTool", "id": "23b7cc26-28ea-4e52-8d2a-a84efe41dc8b"}, {"type": "WheelZoomTool", "id": "88c5a117-ed5b-475a-a801-c0d89769d32d"}, {"type": "BoxZoomTool", "id": "37afa29d-1beb-4925-be2f-eba573a29741"}, {"type": "ResetTool", "id": "90f7a668-849d-4e4d-9b26-a25197017dbb"}, {"type": "PreviewSaveTool", "id": "602f7cfc-1984-45c7-89bd-cbdec5f17f5b"}], "left": [{"type": "LinearAxis", "id": "11f8247c-76c5-439f-bac9-a2e74a2e1d9d"}]}, "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c", "subtype": "Figure"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "73dfb66b-d4dd-4646-921a-8fe53992f772"}, "overlay": {"type": "BoxAnnotation", "id": "22b1305f-07a9-4888-b676-1979b146a88b"}}, "type": "BoxZoomTool", "id": "40918b0b-14fb-4fce-8821-10c8c750d24e"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "59d490ca-3778-4601-92e5-c942ca08961d"}, {"attributes": {}, "type": "ToolEvents", "id": "1895355a-58b8-494b-9eb3-2b47be29474e"}, {"attributes": {"nonselection_glyph": {"type": "Circle", "id": "521446b2-0f5d-49d8-801e-73fb5ab23bcb"}, "data_source": {"type": "ColumnDataSource", "id": "a8c98bd4-c1ba-4375-91b7-b539f67c092f"}, "selection_glyph":  ...

# %% [markdown]
# ## Comparison of Fits

# %% [markdown]
# Examine the error in the shear fit using parameters from the uniaxial fit

# %%
y1 = sf.eval(overlay=uf)
y2 = sf.eval()
err = sqrt(mean((y1-y2)**2)) / average(abs(y2))
print err
show(sf.bp_plot(overlay=[bf, uf]))
show(uf.bp_plot(overlay=[sf]))
show(bf.bp_plot(overlay=[uf, sf]))
# Out:
# 0.0831722323787
#     <div class="plotdiv" id="329a7cb3-3858-4877-a11f-5130393ad773"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("329a7cb3-3858-4877-a11f-5130393ad773");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '329a7cb3-3858-4877-a11f-5130393ad773' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e505734d-569b-4fbb-9af9-43c54acbba22": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c", "73dfb66b-d4dd-4646-921a-8fe53992f772", "8117b6fe-12e9-45a2-b67f-bd02c7e13b5a", "efeee8c3-2938-4093-9aed-e434262c8985"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "c524c00c-e400-4de6-a006-12ec1823702c"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "24dd3ebc-27be-454d-a85b-c073fb238822"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "f37e9663-ae1d-44b4-bbae-9c67deaa6879"}, "data_source": {"type": "ColumnDataSource", "id": "96ea5eda-d32c-403a-9edb-822c640ccccc"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "b1390709-211a-4781-af0d-f562233137ca"}}, "type": "GlyphRenderer", "id": "761dee85-f3af-4580-868d-8037dd9dce71"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "c245361f-def3-456c-8f89-c40685e87801"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [152113.86, 239040.27, 304237.53, 412893.09, 521548.65, 586736.1, 673662.51, 869244.48, 1043087.49, 1216940.31, 1586365.29, 1955790.27, 2303486.1, 2694650.04, 3042345.87, 3390041.7, 3759466.68, 4128891.66, 4476587.49, 4846012.47, 5215447.26, 5584872.24, 6301993.05], "x": [0.1338, 0.2675, 0.3567, 0.6242, 0.8917, 1.1592, 1.4268, 2.051, 2.586, 3.0318, 3.7898, 4.3694, 4.8153, 5.172, 5.4395, 5.707, 5.9299, 6.0637, 6.1975, 6.3312, 6.465, 6.5541, 6.6433]}}, "type": "ColumnDataSource", "id": "a8c98bd4-c1ba-4375-91b7-b539f67c092f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "efeee8c3-2938-4093-9aed-e434262c8985"}, "ticker": {"type": "BasicTicker", "id": "e9b970d1-0571-4bfe-8637-a7de1098fb18"}}, "type": "Grid", "id": "06ff53d9-a9f0-42a9-b39d-3c13c9bd60e5"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "3ce66bf6-63b8-4f7b-a5c6-92c69fa5453f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "efeee8c3-2938-4093-9aed-e434262c8985"}, "formatter": {"type": "BasicTickFormatter", "id": "3fcec448-fd6f-4203-90a9-4ce33279bca5"}, "ticker": {"type": "BasicTicker", "id": "e9b970d1-0571-4bfe-8637-a7de1098fb18"}}, "type": "LinearAxis", "id": "0b310937-b7d3-4f91-b1df-42d3e709a7b5"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "y": {"field": "y"}}, "type": "Line", "id": "63ff996e-ea93-4bee-8a35-3e5263c77bc2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7125d7c7-63d4-43c4-b644-16c781676f8c"}}, "type": "ResetTool", "id": "90f7a668-849d-4e4d-9b26-a25197017dbb"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [58860.0, 156960.0, 235440.0, 329616.0, 412020.0, 588600.0, 765180.0, 941760.0, 1090872.0, 1271376.0, 1459728.0, 1626498.0, 1785420.0], "x": [0.069, 0.1034, 0.1724, 0.2828, 0.4276, 0.8483, 1.3862, 2.0, 2.4897, 3.0345, 3.4483, 3.7793, 4.0621]}}, "type": "ColumnDataSource", "id": "70551815-42b0-4ebc-88c5-740022e05b10"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "73dfb66b-d4dd-4646-921a-8fe53992f772"}}, "type": "WheelZoomTool", "id": "a8d31d7d-d79c-49fc-9585-e773a78b8b89"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "73dfb66b-d4dd-4646-921a-8fe53992f772"}}, "type": "PanTool", "id": "9a747080-6bf5-4dbc-9503-e5417ebc3c78"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "y": {"field": "y"}}, "type": "Line", "id": "cf37b968-482c-4cb7-bc56-7e062d1f0815"}, {"attributes": {"plot": {"subtype": "F ...
#     <div class="plotdiv" id="e3033bf3-89c9-4c1f-9bbd-34cf7f839c93"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e3033bf3-89c9-4c1f-9bbd-34cf7f839c93");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e3033bf3-89c9-4c1f-9bbd-34cf7f839c93' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6ac8bb18-dbc4-4d40-abd2-75aa4223a409": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c", "73dfb66b-d4dd-4646-921a-8fe53992f772", "8117b6fe-12e9-45a2-b67f-bd02c7e13b5a", "efeee8c3-2938-4093-9aed-e434262c8985", "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "c524c00c-e400-4de6-a006-12ec1823702c"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "24dd3ebc-27be-454d-a85b-c073fb238822"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"}, "formatter": {"type": "BasicTickFormatter", "id": "c45ccc76-4f88-457f-aff2-4bf70459ae92"}, "ticker": {"type": "BasicTicker", "id": "20e2ac80-d7ff-4f25-abeb-1bae94a86781"}}, "type": "LinearAxis", "id": "c0347e2a-2362-403f-b81d-a9170e6464b3"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "f37e9663-ae1d-44b4-bbae-9c67deaa6879"}, "data_source": {"type": "ColumnDataSource", "id": "96ea5eda-d32c-403a-9edb-822c640ccccc"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "b1390709-211a-4781-af0d-f562233137ca"}}, "type": "GlyphRenderer", "id": "761dee85-f3af-4580-868d-8037dd9dce71"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"}}, "type": "ResizeTool", "id": "23d5541a-c774-47cf-b7e6-3dc4392612ff"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "c245361f-def3-456c-8f89-c40685e87801"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [152113.86, 239040.27, 304237.53, 412893.09, 521548.65, 586736.1, 673662.51, 869244.48, 1043087.49, 1216940.31, 1586365.29, 1955790.27, 2303486.1, 2694650.04, 3042345.87, 3390041.7, 3759466.68, 4128891.66, 4476587.49, 4846012.47, 5215447.26, 5584872.24, 6301993.05], "x": [0.1338, 0.2675, 0.3567, 0.6242, 0.8917, 1.1592, 1.4268, 2.051, 2.586, 3.0318, 3.7898, 4.3694, 4.8153, 5.172, 5.4395, 5.707, 5.9299, 6.0637, 6.1975, 6.3312, 6.465, 6.5541, 6.6433]}}, "type": "ColumnDataSource", "id": "a8c98bd4-c1ba-4375-91b7-b539f67c092f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "efeee8c3-2938-4093-9aed-e434262c8985"}, "ticker": {"type": "BasicTicker", "id": "e9b970d1-0571-4bfe-8637-a7de1098fb18"}}, "type": "Grid", "id": "06ff53d9-a9f0-42a9-b39d-3c13c9bd60e5"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "c2c381e8-ff3e-4ef4-943b-6bd0e62a0a09"}, "data_source": {"type": "ColumnDataSource", "id": "eb756256-92d9-47f1-aa27-85b4e0da9c8b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "1891c4bb-750f-4e65-bf6e-658947482a3c"}}, "type": "GlyphRenderer", "id": "c5da4124-76fa-4231-a934-cd16255ca80c"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3cb38c09-0012-42eb-9c9d-2c792fa470e7"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "3ce66bf6-63b8-4f7b-a5c6-92c69fa5453f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "efeee8c3-2938-4093-9aed-e434262c8985"}, "formatter": {"type": "BasicTickFormatter", "id": "3fcec448-fd6f-4203-90a9-4ce33279bca5"}, "ticker": {"type": "BasicTicker", "id": "e9b970d1-0571-4bfe-8637-a7de1098fb18"}}, "type": "LinearAxis", "id": "0b310937-b7d3-4f91-b1df-42d3e709a7b5"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [153546.46689341636, 206738.54193867743, 248614.1972561553, 283073.65339559317, 313314.91188024357, 341530.09187116846, 368990.14698046446, 396263.71032261103, ...
#     <div class="plotdiv" id="7930946e-7586-482a-9068-3f7d370593d2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7930946e-7586-482a-9068-3f7d370593d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7930946e-7586-482a-9068-3f7d370593d2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fdb3c97c-b5ba-42e3-a041-b5c97ab71e7e": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c", "73dfb66b-d4dd-4646-921a-8fe53992f772", "8117b6fe-12e9-45a2-b67f-bd02c7e13b5a", "efeee8c3-2938-4093-9aed-e434262c8985", "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa", "e46be94a-ce4a-416f-9f87-a14ca4eb6d43"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "c524c00c-e400-4de6-a006-12ec1823702c"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "24dd3ebc-27be-454d-a85b-c073fb238822"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"}, "formatter": {"type": "BasicTickFormatter", "id": "c45ccc76-4f88-457f-aff2-4bf70459ae92"}, "ticker": {"type": "BasicTicker", "id": "20e2ac80-d7ff-4f25-abeb-1bae94a86781"}}, "type": "LinearAxis", "id": "c0347e2a-2362-403f-b81d-a9170e6464b3"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "f37e9663-ae1d-44b4-bbae-9c67deaa6879"}, "data_source": {"type": "ColumnDataSource", "id": "96ea5eda-d32c-403a-9edb-822c640ccccc"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "b1390709-211a-4781-af0d-f562233137ca"}}, "type": "GlyphRenderer", "id": "761dee85-f3af-4580-868d-8037dd9dce71"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "f030811f-fc55-458e-93a9-33dae26e4f98"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "068a58db-a634-4de8-a538-c7b6669e1759"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e46be94a-ce4a-416f-9f87-a14ca4eb6d43"}}, "type": "ResetTool", "id": "92546928-6c5a-4937-b85f-7d426e08799f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"}}, "type": "ResizeTool", "id": "23d5541a-c774-47cf-b7e6-3dc4392612ff"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "c245361f-def3-456c-8f89-c40685e87801"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [152113.86, 239040.27, 304237.53, 412893.09, 521548.65, 586736.1, 673662.51, 869244.48, 1043087.49, 1216940.31, 1586365.29, 1955790.27, 2303486.1, 2694650.04, 3042345.87, 3390041.7, 3759466.68, 4128891.66, 4476587.49, 4846012.47, 5215447.26, 5584872.24, 6301993.05], "x": [0.1338, 0.2675, 0.3567, 0.6242, 0.8917, 1.1592, 1.4268, 2.051, 2.586, 3.0318, 3.7898, 4.3694, 4.8153, 5.172, 5.4395, 5.707, 5.9299, 6.0637, 6.1975, 6.3312, 6.465, 6.5541, 6.6433]}}, "type": "ColumnDataSource", "id": "a8c98bd4-c1ba-4375-91b7-b539f67c092f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "efeee8c3-2938-4093-9aed-e434262c8985"}, "ticker": {"type": "BasicTicker", "id": "e9b970d1-0571-4bfe-8637-a7de1098fb18"}}, "type": "Grid", "id": "06ff53d9-a9f0-42a9-b39d-3c13c9bd60e5"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "c2c381e8-ff3e-4ef4-943b-6bd0e62a0a09"}, "data_source": {"type": "ColumnDataSource", "id": "eb756256-92d9-47f1-aa27-85b4e0da9c8b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "1891c4bb-750f-4e65-bf6e-658947482a3c"}}, "type": "GlyphRenderer", "id": "c5da4124-76fa-4231-a934-cd16255ca80c"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3cb38c09-0012-42eb-9c9d-2c792fa470e7"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "aeb97ae0-631f-41d2-85e5-145471c6e104"}, {"attributes": { ...

# %% [markdown]
# ## hyperopt2
#
# `hyperopt2` attempts to find the model that fits all given data the best.

# %%
f = hyperopt2(SHEAR_DATA, sd[:,0], sd[:,1], 
              UNIAXIAL_DATA, ud[:,0], ud[:,1],
              BIAXIAL_DATA, bd[:,0], bd[:,1])

# %%
print f.summary()
# Out:
#             Data type: Uniaxial
# Number of data points: 23
#      Polynomial order: 4
#         I2 dependence: False
#            Parameters: C10=430761.746, C20=46252.207, C30=-22262.415, C40=3276.462
#                 Error: 0.0441582062147

# %%
f.error2
# Out:
# 0.0172675902002

# %%
p = f.bp_plot(strain=linspace(0,6.5), points=False)
p.circle(sd[:,0], sd[:,1], color='black', legend='Shear data')
p.circle(bd[:,0], bd[:,1], color='red', legend='Biaxial data')
p.circle(ud[:,0], ud[:,1], color='green', legend='Uniaxial data')
show(p)
# Out:
#     <div class="plotdiv" id="77e91347-0207-4514-a3da-6666a661cad1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77e91347-0207-4514-a3da-6666a661cad1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77e91347-0207-4514-a3da-6666a661cad1' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"75dabd38-8994-4ac4-b228-7a201ad24e96": {"version": "0.11.0", "roots": {"root_ids": ["7125d7c7-63d4-43c4-b644-16c781676f8c", "73dfb66b-d4dd-4646-921a-8fe53992f772", "8117b6fe-12e9-45a2-b67f-bd02c7e13b5a", "efeee8c3-2938-4093-9aed-e434262c8985", "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa", "e46be94a-ce4a-416f-9f87-a14ca4eb6d43", "b8d0a3eb-3d91-4349-ae39-6cea833b4218"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "c524c00c-e400-4de6-a006-12ec1823702c"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "24dd3ebc-27be-454d-a85b-c073fb238822"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"}, "formatter": {"type": "BasicTickFormatter", "id": "c45ccc76-4f88-457f-aff2-4bf70459ae92"}, "ticker": {"type": "BasicTicker", "id": "20e2ac80-d7ff-4f25-abeb-1bae94a86781"}}, "type": "LinearAxis", "id": "c0347e2a-2362-403f-b81d-a9170e6464b3"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "f37e9663-ae1d-44b4-bbae-9c67deaa6879"}, "data_source": {"type": "ColumnDataSource", "id": "96ea5eda-d32c-403a-9edb-822c640ccccc"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "b1390709-211a-4781-af0d-f562233137ca"}}, "type": "GlyphRenderer", "id": "761dee85-f3af-4580-868d-8037dd9dce71"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "f030811f-fc55-458e-93a9-33dae26e4f98"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "068a58db-a634-4de8-a538-c7b6669e1759"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e46be94a-ce4a-416f-9f87-a14ca4eb6d43"}}, "type": "ResetTool", "id": "92546928-6c5a-4937-b85f-7d426e08799f"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "821dfdcc-aa51-46a2-88b6-1ffeb56a198b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "6f7ea8e9-a207-41d9-89f2-4039ba1fb7aa"}}, "type": "ResizeTool", "id": "23d5541a-c774-47cf-b7e6-3dc4392612ff"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "c245361f-def3-456c-8f89-c40685e87801"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "f37e9663-ae1d-44b4-bbae-9c67deaa6879"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y"}}, "type": "Circle", "id": "3391e088-adaf-4c02-8309-909bf8766cf2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "efeee8c3-2938-4093-9aed-e434262c8985"}, "ticker": {"type": "BasicTicker", "id": "e9b970d1-0571-4bfe-8637-a7de1098fb18"}}, "type": "Grid", "id": "06ff53d9-a9f0-42a9-b39d-3c13c9bd60e5"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "c2c381e8-ff3e-4ef4-943b-6bd0e62a0a09"}, "data_source": {"type": "ColumnDataSource", "id": "eb756256-92d9-47f1-aa27-85b4e0da9c8b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "1891c4bb-750f-4e65-bf6e-658947482a3c"}}, "type": "GlyphRenderer", "id": "c5da4124-76fa-4231-a934-cd16255ca80c"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "3cb38c09-0012-42eb-9c9d-2c792fa470e7"}, {"attributes": {"x_range": {"type": "D ...

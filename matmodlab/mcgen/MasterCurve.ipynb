# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mc import *
# %matplotlib inline
init_notebook(plot_lib='matplotlib')

# %%
mc = read_csv('mcgen.test', yvar='E_r', yunits='psi')
show(mc.plot(raw=True))

# %%
mc.fit()
show(mc.plot())

# %%
mc.fit()
show(mc.plot(show_fit=True))

# %%
mc.fit(wlf_coeffs=[2, 300], optimize=False)
show(mc.plot(show_fit=True))

# %%
mc.to_csv('foo.csv')
print open('foo.csv').read()
# Out:
# mcgen
# Version
# 1.2
# Curve Fitter
# Prony
# Curve Fitting Information
# tau_1,tau_2,tau_3,tau_4,tau_5,tau_6,tau_7
# 0.000100000000000000,0.001000000000000000,0.010000000000000000,0.100000000000000006,1.000000000000000000,10.000000000000000000,100.000000000000000000
# y_1,y_2,y_3,y_4,y_5,y_6,y_7,y_inf
# 3151.792989229599697865,1999.638114091135321360,810.563266078882406873,435.084289976224965812,239.322095377865082355,114.163294480134737796,97.133449550844105147,238.101825181016806710
# Fit Error
# 39.581373201190075406
# WLF C1,WLF C2
# 6.793113271188991220,331.323540165621352571
# Data
# Temp,X,Log[X],Y,Log[X/aT]
# 0.000000000000000000,0.010000000000000000,-2.000000000000000000,4857.000000000000000000,-3.987657844495966941
# 0.000000000000000000,0.031600000000000003,-1.500312917381596112,3444.000000000000000000,-3.487970761877563053
# 0.000000000000000000,0.100000000000000006,-1.000000000000000000,2489.000000000000000000,-2.987657844495966941
# ...
